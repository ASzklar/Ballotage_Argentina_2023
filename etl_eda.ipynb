# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
#df_paso = pd.read_csv("data_cruda/ResultadosElectorales_PASO.csv")
df_generales = pd.read_csv("data_cruda/ResultadoElectorales_2023_Generales.csv")
#df_ballotage = pd.read_csv("data_cruda/resultados_ballotage.csv")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_1776\879373075.py:2: DtypeWarning: Columns (9,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_generales = pd.read_csv("Data\ResultadoElectorales_2023_Generales.csv")

# %% [markdown]
# ### PASO

# %%
df_paso['cargo_nombre'].unique()
# Out:
# array(['PRESIDENTE/A', 'DIPUTADOS/AS NACIONALES',
#        'PARLAMENTO MERCOSUR REGIONAL', 'SENADORES/AS PROVINCIALES',
#        'DIPUTADOS/AS PROVINCIALES', 'SENADORES/AS NACIONALES',
#        'GOBERNADOR/A', 'PARLAMENTO MERCOSUR NACIONAL', 'INTENDENTE/A',
#        'CONCEJAL'], dtype=object)

# %%
df_paso.head()
# Out:
#     año eleccion_tipo recuento_tipo padron_tipo  distrito_id distrito_nombre  \
# 0  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
# 1  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
# 2  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
# 3  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
# 4  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
#
#    seccionprovincial_id seccionprovincial_nombre  seccion_id seccion_nombre  \
# 0                     3          Sección Tercera          62          Lanús
# 1                     3          Sección Tercera          62          Lanús
# 2                     3          Sección Tercera          62          Lanús
# 3                     3          Sección Tercera          62          Lanús
# 4                     3          Sección Tercera          62          Lanús
#
# ...

# %%
df_paso = df_paso.loc[df_paso['cargo_nombre'] == 'PRESIDENTE/A']

# %%
df_paso['lista_numero'].unique()
# Out:
# array([3018,    0, 3019, 3025, 3016, 3020, 3011, 3005, 3006, 3001, 3009,
#        3010, 3017, 3008, 3007, 3023, 3022, 3024, 3002, 3003, 3004, 3021,
#        3026, 3027, 3012, 3013, 3014, 3015], dtype=int64)

# %%
df_paso[df_paso['lista_numero'] == 0]
# Out:
#           año eleccion_tipo recuento_tipo padron_tipo  distrito_id  \
# 1        2023          PASO    PROVISORIO      NORMAL            2
# 2        2023          PASO    PROVISORIO      NORMAL            2
# 3        2023          PASO    PROVISORIO      NORMAL            2
# 4        2023          PASO    PROVISORIO      NORMAL            2
# 5        2023          PASO    PROVISORIO      NORMAL            2
# ...       ...           ...           ...         ...          ...
# 3451092  2023          PASO    PROVISORIO      NORMAL           23
# 3451093  2023          PASO    PROVISORIO      NORMAL           23
# 3451094  2023          PASO    PROVISORIO      NORMAL           23
# 3451095  2023          PASO    PROVISORIO      NORMAL           23
# 3451096  2023          PASO    PROVISORIO      NORMAL           23
#
#         distrito_nombre  seccionprovincial_id seccionprovincial_nombre  \
# 1          Buenos Aires                     3          Sección Tercera
# ...

# %%
df_paso.columns
# Out:
# Index(['año', 'eleccion_tipo', 'recuento_tipo', 'padron_tipo', 'distrito_id',
#        'distrito_nombre', 'seccionprovincial_id', 'seccionprovincial_nombre',
#        'seccion_id', 'seccion_nombre', 'circuito_id', 'circuito_nombre',
#        'mesa_id', 'mesa_tipo', 'mesa_electores', 'cargo_id', 'cargo_nombre',
#        'agrupacion_id', 'agrupacion_nombre', 'lista_numero', 'lista_nombre',
#        'votos_tipo', 'votos_cantidad'],
#       dtype='object')

# %%
columnas_a_eliminar = ['año', 'eleccion_tipo', 'recuento_tipo', 'padron_tipo', 'mesa_tipo', 'mesa_electores', 'cargo_id', 'cargo_nombre']

df_paso = df_paso.drop(columns=columnas_a_eliminar)

# %%
df_paso.tail()
# Out:
#          distrito_id distrito_nombre  seccionprovincial_id  \
# 3451107           23         Tucumán                     2
# 3451108           23         Tucumán                     2
# 3451109           23         Tucumán                     2
# 3451110           23         Tucumán                     2
# 3451111           23         Tucumán                     2
#
#         seccionprovincial_nombre  seccion_id seccion_nombre circuito_id  \
# 3451107                     Este          13      Burruyacú       00196
# 3451108                     Este          13      Burruyacú       00196
# 3451109                     Este          13      Burruyacú       00196
# 3451110                     Este          13      Burruyacú       00196
# 3451111                     Este          13      Burruyacú       00196
#
#         circuito_nombre  mesa_id  agrupacion_id         agrupacion_nombre  \
# 3451107           00196     3206             13  MOVIMIENTO AL SOCIALISMO
# ...

# %%
df_paso['agrupacion_nombre'].unique()
# Out:
# array(['UNION DEL CENTRO DEMOCRATICO', nan, 'MOVIMIENTO LIBRES DEL SUR',
#        'MOVIMIENTO DE ACCION VECINAL', 'LA LIBERTAD AVANZA',
#        'POLITICA OBRERA', 'PRINCIPIOS Y VALORES', 'UNION POR LA PATRIA',
#        'HACEMOS POR NUESTRO PAIS',
#        'FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD',
#        'MOVIMIENTO AL SOCIALISMO', 'JUNTOS POR EL CAMBIO',
#        'PROYECTO JOVEN', 'FRENTE LIBER.AR', 'FRENTE PATRIOTA FEDERAL',
#        'MOVIMIENTO IZQUIERDA JUVENTUD Y DIGNIDAD'], dtype=object)

# %%
df_paso_agrupado = df_paso.groupby(['distrito_nombre', 'agrupacion_nombre', 'lista_numero'], as_index=False)['votos_cantidad'].sum()
df_paso_agrupado.head()
# Out:
#   distrito_nombre                               agrupacion_nombre  \
# 0    Buenos Aires  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 1    Buenos Aires  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 2    Buenos Aires                                 FRENTE LIBER.AR
# 3    Buenos Aires                                 FRENTE LIBER.AR
# 4    Buenos Aires                                 FRENTE LIBER.AR
#
#    lista_numero  votos_cantidad
# 0          3009          209110
# 1          3010           84491
# 2          3002            4675
# 3          3003           10159
# 4          3004             989

# %%
df_generales.head()
# Out:
#     año eleccion_tipo recuento_tipo padron_tipo  distrito_id distrito_nombre  \
# 0  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
# 1  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
# 2  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
# 3  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
# 4  2023          PASO    PROVISORIO      NORMAL            2    Buenos Aires
#
#    seccionprovincial_id seccionprovincial_nombre  seccion_id seccion_nombre  \
# 0                     3          Sección Tercera          62          Lanús
# 1                     3          Sección Tercera          62          Lanús
# 2                     3          Sección Tercera          62          Lanús
# 3                     3          Sección Tercera          62          Lanús
# 4                     3          Sección Tercera          62          Lanús
#
# ...

# %% [markdown]
# ### Generales

# %%
df_generales.head()
# Out:
#     año eleccion_tipo  eleccion_id recuento_tipo  recuento_id padron_tipo  \
# 0  2023       GENERAL            2    PROVISORIO            1      NORMAL
# 1  2023       GENERAL            2    PROVISORIO            1      NORMAL
# 2  2023       GENERAL            2    PROVISORIO            1      NORMAL
# 3  2023       GENERAL            2    PROVISORIO            1      NORMAL
# 4  2023       GENERAL            2    PROVISORIO            1      NORMAL
#
#    distrito_id                  distrito_nombre  seccionprovincial_id  \
# 0            1  Ciudad Autónoma de Buenos Aires                   NaN
# 1            1  Ciudad Autónoma de Buenos Aires                   NaN
# 2            1  Ciudad Autónoma de Buenos Aires                   NaN
# 3            1  Ciudad Autónoma de Buenos Aires                   NaN
# 4            1  Ciudad Autónoma de Buenos Aires                   NaN
#
#   seccionprovincial_nombre  seccion_id seccion_nombre circuito_id  \
# ...

# %%
df_generales['cargo_nombre'].unique()
# Out:
# array(['PRESIDENTE Y VICE', 'SENADOR NACIONAL', 'DIPUTADO NACIONAL',
#        'GOBERNADOR Y VICE', 'SENADOR PROVINCIAL', 'DIPUTADO PROVINCIAL',
#        'INTENDENTE', 'PARLAMENTO MERCOSUR NACIONAL',
#        'PARLAMENTO MERCOSUR REGIONAL', 'CONCEJAL', 'JEFE/A DE GOBIERNO',
#        'DIPUTADOS/AS DE LA CIUDAD AUTONOMA', 'MIEMBROS DE JUNTA COMUNAL'],
#       dtype=object)

# %%
df_generales = df_generales.loc[df_generales['cargo_nombre'] == 'PRESIDENTE Y VICE']

# %%
df_generales_agrupado = df_generales.groupby(['distrito_nombre', 'agrupacion_id', 'agrupacion_nombre'], as_index=False)['votos_cantidad'].sum()

# %%
df_generales_agrupado.head(10)
# Out:
#   distrito_nombre  agrupacion_id  \
# 0    Buenos Aires            132
# 1    Buenos Aires            133
# 2    Buenos Aires            134
# 3    Buenos Aires            135
# 4    Buenos Aires            136
# 5       Catamarca            132
# 6       Catamarca            133
# 7       Catamarca            134
# 8       Catamarca            135
# 9       Catamarca            136
#
#                                 agrupacion_nombre  votos_cantidad
# 0                            JUNTOS POR EL CAMBIO         2374023
# 1                        HACEMOS POR NUESTRO PAIS          367457
# 2                             UNION POR LA PATRIA         4224688
# 3                              LA LIBERTAD AVANZA         2533633
# 4  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD          352790
# 5                            JUNTOS POR EL CAMBIO           39960
# 6                        HACEMOS POR NUESTRO PAIS           14967
# ...

# %%
df_generales_agrupado.tail()
# Out:
#     distrito_nombre  agrupacion_id  \
# 115         Tucumán            132
# 116         Tucumán            133
# 117         Tucumán            134
# 118         Tucumán            135
# 119         Tucumán            136
#
#                                   agrupacion_nombre  votos_cantidad
# 115                            JUNTOS POR EL CAMBIO          153130
# 116                        HACEMOS POR NUESTRO PAIS           42086
# 117                             UNION POR LA PATRIA          471145
# 118                              LA LIBERTAD AVANZA          365992
# 119  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD           15152

# %%
df_paso_agrupado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   distrito_nombre    624 non-null    object
#  1   agrupacion_nombre  624 non-null    object
#  2   lista_numero       624 non-null    int64
#  3   votos_cantidad     624 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 19.6+ KB

# %% [markdown]
# ### Ballotage

# %%
df_ballotage.head()
# Out:
#     año   eleccion_tipo  eleccion_id  recuento_id recuento_tipo padron_tipo  \
# 0  2023  SEGUNDA VUELTA            3            1    PROVISORIO      NORMAL
# 1  2023  SEGUNDA VUELTA            3            1    PROVISORIO      NORMAL
# 2  2023  SEGUNDA VUELTA            3            1    PROVISORIO      NORMAL
# 3  2023  SEGUNDA VUELTA            3            1    PROVISORIO      NORMAL
# 4  2023  SEGUNDA VUELTA            3            1    PROVISORIO      NORMAL
#
#    distrito_id                  distrito_nombre  seccion_id seccion_nombre  \
# 0            1  Ciudad Autónoma de Buenos Aires           1      Comuna 01
# 1            1  Ciudad Autónoma de Buenos Aires           1      Comuna 01
# 2            1  Ciudad Autónoma de Buenos Aires           1      Comuna 01
# 3            1  Ciudad Autónoma de Buenos Aires           1      Comuna 01
# 4            1  Ciudad Autónoma de Buenos Aires           1      Comuna 01
#
# ...

# %%
df_ballotage_agrupado = df_ballotage.groupby(['distrito_nombre', 'agrupacion_nombre'], as_index=False)['votos_cantidad'].sum()
df_ballotage_agrupado.head()
# Out:
#   distrito_nombre    agrupacion_nombre  votos_cantidad
# 0    Buenos Aires   LA LIBERTAD AVANZA         4776711
# 1    Buenos Aires  UNION POR LA PATRIA         4919211
# 2    Buenos Aires            undefined          321465
# 3       Catamarca   LA LIBERTAD AVANZA          123588
# 4       Catamarca  UNION POR LA PATRIA          110721

# %%
df_ballotage_agrupado.head()
# Out:
#   distrito_nombre    agrupacion_nombre  votos_cantidad
# 0    Buenos Aires   LA LIBERTAD AVANZA         4776711
# 1    Buenos Aires  UNION POR LA PATRIA         4919211
# 2    Buenos Aires            undefined          321465
# 3       Catamarca   LA LIBERTAD AVANZA          123588
# 4       Catamarca  UNION POR LA PATRIA          110721

# %% [markdown]
# ### Exportamos la data limpia

# %%
df_paso_agrupado.to_csv('data_limpia/paso.csv', index=False)
df_generales_agrupado.to_csv('data_limpia/generales.csv', index=False)
df_ballotage_agrupado.to_csv('data_limpia/ballotage.csv', index=False)
